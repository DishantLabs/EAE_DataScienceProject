# %% [markdown]
# <a href="https://colab.research.google.com/github/DishantLabs/EAE_DataScienceProject/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Machine Learning for Improved Snow Classification in Cloudy Mountain Environments**

# %% [markdown]
# Edit
